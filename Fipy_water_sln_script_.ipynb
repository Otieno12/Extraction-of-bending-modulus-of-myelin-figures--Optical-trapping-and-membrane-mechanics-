# %%
! pip install fipy
# Out:
# Collecting fipy
#   Downloading fipy-4.0.2-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from fipy) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from fipy) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from fipy) (3.10.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from fipy) (0.24.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from fipy) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fipy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fipy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fipy) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fipy) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fipy) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fipy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fipy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fipy) (2.9.0.post0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->fipy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->fipy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->fipy) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->fipy) (0.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->fipy) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->fipy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->fipy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->fipy) (0.1.2)
# Downloading fipy-4.0.2-py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.1/441.1 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: fipy
# Successfully installed fipy-4.0.2

# %%
import numpy as np
import matplotlib.pyplot as plt

# time (seconds)
t = np.array([5,10,15,20,25,30,35,40,45,50,55,60,70,80])

# average length (µm)
L_um = np.array([
29.09445455,	37.63181818,	40.90190909,	50.41254545	,50.18236364,	51.28754545,49.38772727,	45.8127,	45.488,	43.50177778,	43.734,	42.955625,44.45185714,	43.799
])

# convert to meters
L = L_um * 1e-6

# %% [markdown]
# Here we use the average values extracted from the microscopic images

# %%
L2 = L**2

# linear fit
coeff = np.polyfit(t, L2, 1)

D = coeff[0]

print("Diffusion coefficient:", D)
# Out:
# Diffusion coefficient: 4.391981549240889e-12

# %% [markdown]
# remember the diffusion law is a partial differential equation -applying diffusion growth law
#
# 𝐿^2=𝐷𝑡

# %%
plt.scatter(t, L2, label="Experiment")

plt.plot(t, coeff[0]*t + coeff[1],
         label="Linear fit")

plt.xlabel("Time (s)")
plt.ylabel("L² (m²)")
plt.legend()
plt.show()

# %%
from fipy import CellVariable, Grid1D, TransientTerm, DiffusionTerm

# domain
length_domain = 45e-6
nx = 200
dx = length_domain / nx

mesh = Grid1D(nx=nx, dx=dx)

# concentration field
C = CellVariable(mesh=mesh, value=0.)

# diffusion coefficient
D = 4.39e-11

# diffusion equation
eq = TransientTerm() == DiffusionTerm(coeff=D)

# reservoir boundary
C.constrain(1.0, mesh.facesLeft)

dt = 0.5
steps =200

tube_length = []
time = []

for step in range(steps):

    eq.solve(var=C, dt=dt)

    # estimate tube length
    L_tube = np.sum(C.value > 0.2) * dx

    tube_length.append(L_tube)
    time.append(step * dt)

# %%
plt.plot(time, np.array(tube_length)*1e6,
         label="Simulation")

plt.scatter(t, L_um,
            label="Experiment",color='red')

plt.xlabel("Time (s)")
plt.ylabel("Tube length (µm)")
plt.legend()
plt.show()

# %% [markdown]
# possible retraction and thickning of the tubes -low the D the better the fitting between the experimental and simulatory results (water solution )

# %% [markdown]
# question here is does diffusion coefficient of different solvents influencces the growth dynamics which we refers to morphodynamics -therefore we can state that it is a diffusion limited process which rely heavily on the thickness of the tubes due to diffusion and the structural situation of the lump

# %% [markdown]
# differences from simulation and experimental length is purely based of other factor

# %% [markdown]
# now we simulate and we will compare experimental vs simualtion above script does the finite simulation based of the diffusion law
